# %%
# !pip install neo4j

# %%
import logging
import os
import sys
import ast
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from neo4j import GraphDatabase
from neo4j.exceptions import DriverError, SessionError

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier
import optuna

class CoraNeo4jConnector:

    def __init__(self, uri, user, password, logfile):
        if os.path.exists(logfile):
            logging.basicConfig(filename=logfile, encoding='utf-8', level=logging.INFO)
            self.driver = GraphDatabase.driver(uri, auth=(user, password))
            assert self.__verify_driver_and_connection() is True, "Neo4j connection cannot be verified!"
            logging.info("Driver has been initialized and connected successfully!")
            logging.info(f'''
Server Info:
"Address: {self.driver.get_server_info().address}
"Protocol Version: {self.driver.get_server_info().protocol_version}
"Agent: {self.driver.get_server_info().agent}
''')
        else:
            raise FileNotFoundError("Logger file does not exist!")

    def __verify_driver_and_connection(self):
        if self.driver is None:
            return False
        try:
            self.driver.verify_connectivity()
            return True
        except DriverError as err:
            logging.error(f"Connection cannot be verified!, {err}")
            self.driver.close()
            return False

    def query(self, cypher, *parameters):
        assert self.__verify_driver_and_connection() is True, "Neo4j connection cannot be verified!"
        try:
            with self.driver.session() as session:
                result = list(session.run(cypher, parameters))
                logging.info(f"Query: {cypher} is sent to the database and the result is returned to the caller!")
                return result
        except SessionError as err:
            print(f"Query: {cypher} is failed!")
            logging.error(f"Query: {cypher} is failed!")

    def close(self):
        assert self.__verify_driver_and_connection() is True, "Neo4j connection cannot be verified!"
        self.driver.close()

    def clear_entire_db(self):
        assert self.__verify_driver_and_connection() is True, "Neo4j connection cannot be verified!"
        try:
            with self.driver.session() as session:
                session.execute_write(CoraNeo4jConnector.__clear_entire_db, "MATCH (n) DETACH DELETE n")
            logging.info("Database is cleared successfully!")
        except SessionError as err:
            logging.error(f"cannot clear entire db {err}")

    @staticmethod
    def __clear_entire_db(tx, cypher):
        # all nodes and relationships
        result = tx.run(cypher)
        result.consume()

    def load_cora_nodes(self):
        assert self.__verify_driver_and_connection() is True, "Neo4j connection cannot be verified!"
        try:
            with self.driver.session() as session:
                result = session.run(
                    "CREATE CONSTRAINT paper_constraint IF NOT EXISTS FOR (p:Paper) REQUIRE p.id IS UNIQUE")
                _ = result.single()
                logging.info("Constraint is created on Paper for unique id!")
                record = session.execute_write(CoraNeo4jConnector.__load_cora_nodes_and_return_node_count)
                _ = record[0]
                logging.info("Nodes are loaded to database successfully!")
        except IndexError:
            logging.error(f"Record does not have given index, load_cora_nodes!")
            sys.exit(-1)
        except SessionError as err:
            logging.error(f"cannot load nodes to db, {err}")

    @staticmethod
    def __load_cora_nodes_and_return_node_count(tx):

        cypher = """
LOAD CSV WITH HEADERS FROM 'https://cora-dataset.s3.eu-central-1.amazonaws.com/dataset/nodes.csv' AS row
WITH row
MERGE (p:Paper {id: row.paper_id, subject: row.subject, words: row.words})
REMOVE p.features
RETURN COUNT(*)
"""
        # idempotent operation
        result = tx.run(cypher)
        return result.single()

    def load_cora_edges(self):
        try:
            with self.driver.session() as session:
                record = session.execute_write(CoraNeo4jConnector.__load_cora_edges_and_return_node_count)
                _ = record[0]
                logging.info("Edges are loaded successfully")
        except IndexError:
            logging.error(f"Record does not have given index, load_cora_edges!")
            sys.exit(-1)
        except SessionError as err:
            logging.error(f"cannot load given edges to db, {err}")

    @staticmethod
    def __load_cora_edges_and_return_node_count(tx):

        cypher = """
LOAD CSV WITH HEADERS FROM 'https://cora-dataset.s3.eu-central-1.amazonaws.com/dataset/edges.csv' AS row
WITH row
MATCH (to:Paper {id: row.cited_paper_id})
MATCH (from:Paper {id: row.citing_paper_id})
MERGE (from)-[:CITED]->(to)
RETURN COUNT(*)
"""
        # idempotent operation
        result = tx.run(cypher)
        return result.single()

# %%
def load_cora_to_neo4j(d):
    try:
        d.clear_entire_db()
        d.load_cora_nodes()
        d.load_cora_edges()
    except Exception:
        print("Cora dataset cannot be loaded to neo4j!")
    return

def create_in_memory_graph(d):
    d.query('''
    CALL gds.graph.project(
       'Cora',
       'Paper',
       {CITED:
           {
               orientation: 'UNDIRECTED'
           }
       }
    )''')
    return

with open("auth.json", "r") as auth:
    auth = json.load(auth)
    driver = CoraNeo4jConnector(auth["URI"],
                            auth["USER"],
                            auth["PASSWORD"],
                            auth["LOGFILE"])
    # cora dataset is already loaded to neo4j instance in the cloud
    # load_cora_to_neo4j(driver)
    # create_in_memory_graph(driver)

# %%
# loading database back to DataFrame to apply machine learning tasks
query = "MATCH (p:Paper) RETURN p.id AS id, p.subject AS subject, p.words AS words"
df_cora = pd.DataFrame([dict(row) for row in driver.query(query)])
df_cora['words'] = df_cora['words'].apply(ast.literal_eval)
df_cora['words'] = df_cora['words'].apply(lambda x: np.array(x, dtype=float))

# %%
def random_forest_without_embedding(k_folds=5, show_matrix=True):
    acc_scores = []

    # create X and y value for the scikit-learn
    X = np.array(df_cora['words'].to_list())
    y = np.array(df_cora['subject'].factorize()[0], dtype=float)

    for _ in range(0, k_folds):

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50)
        clf = RandomForestClassifier(max_depth=500, random_state=0)
        clf.fit(X_train, y_train)
        pred = clf.predict(X_test)

        acc = accuracy_score(pred, y_test)
        acc_scores.append(acc)

    print('Accuracy scores: ', acc_scores)
    print('Mean accuracy: ', np.mean(acc_scores))

    if show_matrix:
        disp = ConfusionMatrixDisplay.from_estimator(
            clf,
            X_test,
            y_test,
            display_labels=clf.classes_,
            cmap=plt.cm.Blues,
            normalize='true'
        )
        disp.ax_.set_title("Random forest without embedding")
    return

random_forest_without_embedding()

# %%
def create_fastrp_embedding(dim=10):
    query = """CALL gds.fastRP.write(
               'Cora',
               {
                   embeddingDimension: %d,
                   iterationWeights: [0.0, 0.0, 1.0, 1.0],
                   writeProperty: 'fastrp_embedding'
               }
           )
    """ % (dim)
    driver.query(query)
    return

# %%
def random_forest_with_fastrp(dim, k_folds=5, show_matrix=True):
    acc_scores = []

    create_fastrp_embedding(dim)
    # create X and y value for the scikit-learn
    query = """MATCH (p:Paper) RETURN p.id AS id, p.subject AS subject, p.fastrp_embedding AS fastrp_embedding"""
    df_embedding = pd.DataFrame([dict(row) for row in driver.query(query)])
    df_embedding['X'] = np.array(df_embedding['fastrp_embedding'].apply(lambda x: np.array(x)))
    X = np.array(df_embedding['X'].to_list())
    y = np.array(df_cora['subject'].factorize()[0], dtype=float)

    for _ in range(0, k_folds):

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
        clf = RandomForestClassifier(max_depth=500, random_state=0)
        clf.fit(X_train, y_train)
        pred = clf.predict(X_test)

        acc = accuracy_score(pred, y_test)
        acc_scores.append(acc)

    print('Accuracy scores: ', acc_scores)
    print('Mean accuracy: ', np.mean(acc_scores))

    if show_matrix:
        disp = ConfusionMatrixDisplay.from_estimator(
            clf,
            X_test,
            y_test,
            display_labels=clf.classes_,
            cmap=plt.cm.Blues,
            normalize='true'
        )
        disp.ax_.set_title("Random forest with FastRP embedding")
    return

random_forest_with_fastrp(dim=506)

# %%
def create_node2vec_embedding(embedding_dimension=128, walk_length=250, return_factor=1.0, in_out_factor=2.0):
    query = """CALL gds.beta.node2vec.write(
               'Cora',
               {
                   embeddingDimension: %d,
                   returnFactor: %d,
                   inOutFactor: %d,
                   walkLength: %d,
                   writeProperty: 'node2vec_embedding'
               }
           )
    """ % (embedding_dimension, return_factor, in_out_factor, walk_length)
    driver.query(query)
    return
# create X and y value for the scikit-learn
query = """MATCH (p:Paper) RETURN p.id AS id, p.subject AS subject, p.node2vec_embedding AS node2vec_embedding"""
df_embedding = pd.DataFrame([dict(row) for row in driver.query(query)])
df_embedding['X'] = np.array(df_embedding['node2vec_embedding'].apply(lambda x: np.array(x)))
X = np.array(df_embedding['X'].to_list())
y = np.array(df_cora['subject'].factorize()[0], dtype=float)

def opt_for_node2vec(params):
    acc_scores = []
    k_folds = 5

    for _ in range(0, k_folds):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
        clf = RandomForestClassifier(max_depth=500, random_state=0)
        clf.fit(X_train, y_train)
        pred = clf.predict(X_test)

        acc = accuracy_score(pred, y_test)
        acc_scores.append(acc)

    return np.mean(acc_scores)

def objective_learn_node2vec():

    def objective(params):

        embedding_dimension = params['embeddingDimension']
        return_factor = params['returnFactor']
        in_out_factor = params['inOutFactor']
        walk_length = params['walkLength']

        # Create embeddings
        query = """CALL gds.beta.node2vec.write(
               'Cora',
               {
                   embeddingDimension: %d,
                   returnFactor: %d,
                   inOutFactor: %d,
                   walkLength: %d,
                   writeProperty: 'node2vec_embedding'
               }
           )
    """ % (embedding_dimension, return_factor, in_out_factor, walk_length)

        driver.query(query)

        return opt_for_node2vec(params)

    return objective

def optuna_objective_node2vec(trial):

    params = {
        'embeddingDimension': trial.suggest_int('embeddingDimension', 30, 700, log=True),
        'returnFactor': trial.suggest_float('returnFactor', 0.1, 5.0),
        'inOutFactor': trial.suggest_float('inOutFactor', 0.1, 5.0),
        'walkLength': trial.suggest_int('walkLength', 2, 700)
    }

    objective = objective_learn_node2vec()

    return objective(params)

def optuna_apply():
    initial_params = {
        'embeddingDimension': 111,
        'returnFactor': 2.9,
        'inOutFactor': 3.1,
        'walkLength': 150
    }

    study = optuna.create_study(direction='maximize')
    study.enqueue_trial(initial_params)
    study.optimize(optuna_objective_node2vec, n_trials=100)

    print('Accuracy: {}'.format(study.best_trial.value))
    print('Best hyperparameters: {}'.format(study.best_trial.params))

def random_forest_with_node2vec(embedding_dimension=128, k_folds=5, show_matrix=True):
    acc_scores = []

    create_node2vec_embedding(embedding_dimension=embedding_dimension, walk_length=80, return_factor=0.5, in_out_factor=2.0)
    # create X and y value for the scikit-learn
    query = """MATCH (p:Paper) RETURN p.id AS id, p.subject AS subject, p.node2vec_embedding AS node2vec_embedding"""
    df_embedding = pd.DataFrame([dict(row) for row in driver.query(query)])
    df_embedding['X'] = np.array(df_embedding['node2vec_embedding'].apply(lambda x: np.array(x)))
    X = np.array(df_embedding['X'].to_list())
    y = np.array(df_cora['subject'].factorize()[0], dtype=float)

    for _ in range(0, k_folds):

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
        clf = RandomForestClassifier(max_depth=500, random_state=0)
        clf.fit(X_train, y_train)
        pred = clf.predict(X_test)

        acc = accuracy_score(pred, y_test)
        acc_scores.append(acc)

    print('Accuracy scores: ', acc_scores)
    print('Mean accuracy: ', np.mean(acc_scores))

    if show_matrix:
        disp = ConfusionMatrixDisplay.from_estimator(
            clf,
            X_test,
            y_test,
            display_labels=clf.classes_,
            cmap=plt.cm.Blues,
            normalize='true'
        )
        disp.ax_.set_title("Random forest with Node2vec embedding")
    return

optuna_apply()
# random_forest_with_node2vec(embedding_dimension=506)
# Out:
# [I 2023-01-11 06:32:11,861] A new study created in memory with name: no-name-ee3262ca-5612-4485-bfc1-58cb7281954d
# [I 2023-01-11 06:32:27,391] Trial 0 finished with value: 0.86794682422452 and parameters: {'embeddingDimension': 111, 'returnFactor': 2.9, 'inOutFactor': 3.1, 'walkLength': 150}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:33:24,107] Trial 1 finished with value: 0.863810930576071 and parameters: {'embeddingDimension': 234, 'returnFactor': 3.6292918987687357, 'inOutFactor': 4.588967834962466, 'walkLength': 540}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:34:07,550] Trial 2 finished with value: 0.862629246676514 and parameters: {'embeddingDimension': 50, 'returnFactor': 4.8709780962860085, 'inOutFactor': 0.7556254254369404, 'walkLength': 259}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:35:33,212] Trial 3 finished with value: 0.8596750369276218 and parameters: {'embeddingDimension': 287, 'returnFactor': 4.03534945002248, 'inOutFactor': 2.413363721868443, 'walkLength': 663}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:35:55,416] Trial 4 finished with value: 0.8546528803545052 and parameters: {'embeddingDimension': 184, 'returnFactor': 2.12131492113574, 'inOutFactor': 2.1519210613937667, 'walkLength': 181}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:36:15,441] Trial 5 finished with value: 0.8522895125553914 and parameters: {'embeddingDimension': 64, 'returnFactor': 4.989385589400613, 'inOutFactor': 3.186188915196682, 'walkLength': 259}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:36:54,000] Trial 6 finished with value: 0.8525849335302806 and parameters: {'embeddingDimension': 255, 'returnFactor': 3.3823257237225084, 'inOutFactor': 4.798769316825578, 'walkLength': 287}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:38:16,392] Trial 7 finished with value: 0.8623338257016249 and parameters: {'embeddingDimension': 111, 'returnFactor': 0.919430628234501, 'inOutFactor': 2.4450373249724335, 'walkLength': 521}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:38:56,563] Trial 8 finished with value: 0.8564254062038404 and parameters: {'embeddingDimension': 351, 'returnFactor': 3.9304778532574436, 'inOutFactor': 1.1672146900668599, 'walkLength': 241}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:39:32,675] Trial 9 finished with value: 0.8581979320531758 and parameters: {'embeddingDimension': 53, 'returnFactor': 2.800912973094932, 'inOutFactor': 1.551196280467878, 'walkLength': 619}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:39:39,893] Trial 10 finished with value: 0.8620384047267355 and parameters: {'embeddingDimension': 693, 'returnFactor': 1.5622481193384392, 'inOutFactor': 3.6843065304551255, 'walkLength': 7}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:40:19,070] Trial 11 finished with value: 0.854357459379616 and parameters: {'embeddingDimension': 110, 'returnFactor': 2.7348656734866186, 'inOutFactor': 4.985879448774064, 'walkLength': 472}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:40:28,943] Trial 12 finished with value: 0.8590841949778433 and parameters: {'embeddingDimension': 32, 'returnFactor': 3.5558742747873016, 'inOutFactor': 3.981640631171313, 'walkLength': 66}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:41:53,034] Trial 13 finished with value: 0.8499261447562778 and parameters: {'embeddingDimension': 155, 'returnFactor': 1.9565419368686525, 'inOutFactor': 0.1311028708508455, 'walkLength': 414}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:42:31,641] Trial 14 finished with value: 0.8587887740029542 and parameters: {'embeddingDimension': 449, 'returnFactor': 0.28469716661480327, 'inOutFactor': 4.177439335629822, 'walkLength': 133}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:43:01,796] Trial 15 finished with value: 0.8611521418020679 and parameters: {'embeddingDimension': 92, 'returnFactor': 3.217642037633904, 'inOutFactor': 3.2724538020591663, 'walkLength': 380}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:44:03,386] Trial 16 finished with value: 0.8555391432791728 and parameters: {'embeddingDimension': 201, 'returnFactor': 4.3422666053978585, 'inOutFactor': 4.428516783519401, 'walkLength': 558}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:45:14,800] Trial 17 finished with value: 0.8646971935007386 and parameters: {'embeddingDimension': 490, 'returnFactor': 2.443566718560304, 'inOutFactor': 3.1690888213675197, 'walkLength': 349}. Best is trial 0 with value: 0.86794682422452.
# [I 2023-01-11 06:46:36,453] Trial 18 finished with value: 0.869423929098966 and parameters: {'embeddingDimension': 626, 'returnFactor': 1.5113073833738055, 'inOutFactor': 3.0557581834772205, 'walkLength': 331}. Best is trial 18 with value: 0.869423929098966.
# [I 2023-01-11 06:46:49,157] Trial 19 finished with value: 0.8579025110782865 and parameters: {'embeddingDimension': 81, 'returnFactor': 1.2369918890821816, 'inOutFactor': 1.8801663818158205, 'walkLength': 111}. Best is trial 18 with value: 0.869423929098966.
# [I 2023-01-11 06:47:17,462] Trial 20 finished with value: 0.8635155096011816 and parameters: {'embeddingDimension': 32, 'returnFactor': 0.5556615596081453, 'inOutFactor': 2.757229482450374, 'walkLength': 187}. Best is trial 18 with value: 0.869423929098966.
# [I 2023-01-11 06:48:38,267] Trial 21 finished with value: 0.8629246676514033 and parameters: {'embeddingDimension': 624, 'returnFactor': 2.2321172046603235, 'inOutFactor': 3.149190936467051, 'walkLength': 329}. Best is trial 18 with value: 0.869423929098966.
# [I 2023-01-11 06:50:02,770] Trial 22 finished with value: 0.8658788774002953 and parameters: {'embeddingDimension': 470, 'returnFactor': 1.5695397846248476, 'inOutFactor': 3.5558858164785496, 'walkLength': 432}. Best is trial 18 with value: 0.869423929098966.
# [I 2023-01-11 06:51:21,852] Trial 23 finished with value: 0.8697193500738551 and parameters: {'embeddingDimension': 400, 'returnFactor': 1.5362706008860219, 'inOutFactor': 3.607534052585234, 'walkLength': 460}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 06:52:28,471] Trial 24 finished with value: 0.854357459379616 and parameters: {'embeddingDimension': 306, 'returnFactor': 1.7454054033173223, 'inOutFactor': 2.841910008261809, 'walkLength': 462}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 06:53:25,233] Trial 25 finished with value: 0.8581979320531758 and parameters: {'embeddingDimension': 383, 'returnFactor': 1.2358645869998441, 'inOutFactor': 3.8604290218106554, 'walkLength': 326}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 06:54:11,311] Trial 26 finished with value: 0.8593796159527326 and parameters: {'embeddingDimension': 566, 'returnFactor': 3.0608522682513923, 'inOutFactor': 3.5642880729321478, 'walkLength': 191}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 06:54:57,490] Trial 27 finished with value: 0.8555391432791728 and parameters: {'embeddingDimension': 151, 'returnFactor': 1.0744676800485207, 'inOutFactor': 2.927319172784695, 'walkLength': 489}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 06:56:35,796] Trial 28 finished with value: 0.865288035450517 and parameters: {'embeddingDimension': 382, 'returnFactor': 2.447887657733828, 'inOutFactor': 2.1066025421746852, 'walkLength': 597}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 06:56:44,637] Trial 29 finished with value: 0.8581979320531758 and parameters: {'embeddingDimension': 119, 'returnFactor': 0.6962361663784862, 'inOutFactor': 4.370698453716166, 'walkLength': 18}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 06:57:32,353] Trial 30 finished with value: 0.865288035450517 and parameters: {'embeddingDimension': 230, 'returnFactor': 1.9474433191733813, 'inOutFactor': 3.445736652361118, 'walkLength': 392}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 06:59:00,153] Trial 31 finished with value: 0.8593796159527327 and parameters: {'embeddingDimension': 487, 'returnFactor': 1.3738418271154795, 'inOutFactor': 3.947320927029665, 'walkLength': 434}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:01:00,771] Trial 32 finished with value: 0.8590841949778435 and parameters: {'embeddingDimension': 554, 'returnFactor': 1.6655811131253084, 'inOutFactor': 3.577444746226042, 'walkLength': 551}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:02:49,678] Trial 33 finished with value: 0.8649926144756279 and parameters: {'embeddingDimension': 414, 'returnFactor': 0.11862749210588186, 'inOutFactor': 2.739736049232535, 'walkLength': 433}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:03:33,546] Trial 34 finished with value: 0.8644017725258495 and parameters: {'embeddingDimension': 298, 'returnFactor': 1.5171011684091475, 'inOutFactor': 2.44298503431389, 'walkLength': 298}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:05:47,532] Trial 35 finished with value: 0.8576070901033972 and parameters: {'embeddingDimension': 692, 'returnFactor': 2.206664949594977, 'inOutFactor': 3.0322055111799884, 'walkLength': 509}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:06:13,194] Trial 36 finished with value: 0.8552437223042835 and parameters: {'embeddingDimension': 173, 'returnFactor': 2.8981415783398132, 'inOutFactor': 3.390934183146754, 'walkLength': 214}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:08:21,746] Trial 37 finished with value: 0.8605612998522896 and parameters: {'embeddingDimension': 224, 'returnFactor': 0.781846405240658, 'inOutFactor': 4.1794865570848865, 'walkLength': 692}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:08:49,690] Trial 38 finished with value: 0.8641063515509602 and parameters: {'embeddingDimension': 76, 'returnFactor': 2.506103047123889, 'inOutFactor': 2.167292842022646, 'walkLength': 379}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:09:33,862] Trial 39 finished with value: 0.8614475627769572 and parameters: {'embeddingDimension': 325, 'returnFactor': 1.9818578215574951, 'inOutFactor': 2.6119640257259396, 'walkLength': 282}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:09:50,727] Trial 40 finished with value: 0.8584933530280651 and parameters: {'embeddingDimension': 131, 'returnFactor': 4.507379320965127, 'inOutFactor': 3.8555645177886073, 'walkLength': 143}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:10:40,440] Trial 41 finished with value: 0.863810930576071 and parameters: {'embeddingDimension': 240, 'returnFactor': 1.7398786935651156, 'inOutFactor': 3.504144397415386, 'walkLength': 399}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:12:13,381] Trial 42 finished with value: 0.862629246676514 and parameters: {'embeddingDimension': 503, 'returnFactor': 1.9072989989452211, 'inOutFactor': 3.390334683061809, 'walkLength': 453}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:13:02,619] Trial 43 finished with value: 0.8537666174298375 and parameters: {'embeddingDimension': 270, 'returnFactor': 1.0498195746228243, 'inOutFactor': 3.691528216909041, 'walkLength': 364}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:14:01,219] Trial 44 finished with value: 0.8605612998522896 and parameters: {'embeddingDimension': 593, 'returnFactor': 2.2611925788887035, 'inOutFactor': 3.014420520310733, 'walkLength': 242}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:15:27,154] Trial 45 finished with value: 0.857016248153619 and parameters: {'embeddingDimension': 397, 'returnFactor': 1.4658507054647258, 'inOutFactor': 4.18116585405417, 'walkLength': 499}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:16:31,495] Trial 46 finished with value: 0.8685376661742984 and parameters: {'embeddingDimension': 343, 'returnFactor': 2.7062522913080036, 'inOutFactor': 4.597857487741871, 'walkLength': 411}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:17:07,802] Trial 47 finished with value: 0.8564254062038404 and parameters: {'embeddingDimension': 42, 'returnFactor': 3.553284756087056, 'inOutFactor': 4.729754216267693, 'walkLength': 611}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:18:13,199] Trial 48 finished with value: 0.8682422451994091 and parameters: {'embeddingDimension': 344, 'returnFactor': 3.2864322271971647, 'inOutFactor': 4.427334638292093, 'walkLength': 424}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:19:33,173] Trial 49 finished with value: 0.8558345642540621 and parameters: {'embeddingDimension': 337, 'returnFactor': 3.918061429010283, 'inOutFactor': 4.998093052155151, 'walkLength': 530}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:20:13,383] Trial 50 finished with value: 0.8558345642540619 and parameters: {'embeddingDimension': 209, 'returnFactor': 3.1707752783127927, 'inOutFactor': 4.589011931409447, 'walkLength': 337}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:21:37,832] Trial 51 finished with value: 0.8655834564254062 and parameters: {'embeddingDimension': 486, 'returnFactor': 2.6696085363874524, 'inOutFactor': 4.384883319778478, 'walkLength': 425}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:23:05,882] Trial 52 finished with value: 0.8635155096011816 and parameters: {'embeddingDimension': 437, 'returnFactor': 2.9734043924353006, 'inOutFactor': 4.7627316821143415, 'walkLength': 478}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:23:41,030] Trial 53 finished with value: 0.8605612998522896 and parameters: {'embeddingDimension': 95, 'returnFactor': 3.4078682269096228, 'inOutFactor': 4.105055445289923, 'walkLength': 448}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:23:57,240] Trial 54 finished with value: 0.8688330871491876 and parameters: {'embeddingDimension': 348, 'returnFactor': 3.7085098821918434, 'inOutFactor': 4.531217574997854, 'walkLength': 74}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:24:10,549] Trial 55 finished with value: 0.8570162481536189 and parameters: {'embeddingDimension': 270, 'returnFactor': 3.7899538232425036, 'inOutFactor': 4.521641399135985, 'walkLength': 62}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:24:24,237] Trial 56 finished with value: 0.8564254062038403 and parameters: {'embeddingDimension': 187, 'returnFactor': 4.252915813150206, 'inOutFactor': 4.610051245737039, 'walkLength': 85}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:24:32,209] Trial 57 finished with value: 0.8632200886262925 and parameters: {'embeddingDimension': 62, 'returnFactor': 3.357489180727639, 'inOutFactor': 4.288928330919931, 'walkLength': 37}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:25:00,057] Trial 58 finished with value: 0.8549483013293944 and parameters: {'embeddingDimension': 346, 'returnFactor': 2.643866332822434, 'inOutFactor': 3.783505985301885, 'walkLength': 162}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:25:21,916] Trial 59 finished with value: 0.8573116691285081 and parameters: {'embeddingDimension': 369, 'returnFactor': 2.861807908702858, 'inOutFactor': 4.829348335490024, 'walkLength': 110}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:27:42,954] Trial 60 finished with value: 0.8673559822747414 and parameters: {'embeddingDimension': 640, 'returnFactor': 3.6891217882483778, 'inOutFactor': 4.014061839366438, 'walkLength': 578}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:29:03,972] Trial 61 finished with value: 0.8567208271787298 and parameters: {'embeddingDimension': 666, 'returnFactor': 3.776209411940901, 'inOutFactor': 4.021917940915633, 'walkLength': 308}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:31:13,108] Trial 62 finished with value: 0.8564254062038404 and parameters: {'embeddingDimension': 543, 'returnFactor': 3.2856708243174277, 'inOutFactor': 4.480748089851654, 'walkLength': 594}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:34:31,005] Trial 63 finished with value: 0.869423929098966 and parameters: {'embeddingDimension': 604, 'returnFactor': 3.490748809132308, 'inOutFactor': 0.41103891698877115, 'walkLength': 579}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:36:23,186] Trial 64 finished with value: 0.8685376661742984 and parameters: {'embeddingDimension': 428, 'returnFactor': 3.4914746630734594, 'inOutFactor': 1.1178332304959437, 'walkLength': 637}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:39:27,148] Trial 65 finished with value: 0.866765140324963 and parameters: {'embeddingDimension': 428, 'returnFactor': 4.141527955039399, 'inOutFactor': 0.5356712508664274, 'walkLength': 639}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:42:51,120] Trial 66 finished with value: 0.8614475627769572 and parameters: {'embeddingDimension': 528, 'returnFactor': 3.51009014362458, 'inOutFactor': 0.900016630733081, 'walkLength': 636}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:45:38,874] Trial 67 finished with value: 0.8596750369276218 and parameters: {'embeddingDimension': 302, 'returnFactor': 3.1707598718014287, 'inOutFactor': 0.19528732336546378, 'walkLength': 665}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:47:46,855] Trial 68 finished with value: 0.8561299852289512 and parameters: {'embeddingDimension': 443, 'returnFactor': 3.8585061841383927, 'inOutFactor': 1.484536820115173, 'walkLength': 700}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:51:02,269] Trial 69 finished with value: 0.8590841949778435 and parameters: {'embeddingDimension': 614, 'returnFactor': 4.78264612990786, 'inOutFactor': 0.6501586864551112, 'walkLength': 553}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:52:37,807] Trial 70 finished with value: 0.863810930576071 and parameters: {'embeddingDimension': 390, 'returnFactor': 4.067572735809817, 'inOutFactor': 1.2764006147534337, 'walkLength': 574}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:53:08,641] Trial 71 finished with value: 0.8599704579025111 and parameters: {'embeddingDimension': 99, 'returnFactor': 3.1468889350467237, 'inOutFactor': 3.2536908355279692, 'walkLength': 367}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:54:25,009] Trial 72 finished with value: 0.862629246676514 and parameters: {'embeddingDimension': 322, 'returnFactor': 3.4563430309586862, 'inOutFactor': 2.282406823429851, 'walkLength': 519}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:55:48,839] Trial 73 finished with value: 0.8661742983751847 and parameters: {'embeddingDimension': 135, 'returnFactor': 2.9909889055648824, 'inOutFactor': 0.26244762365199015, 'walkLength': 404}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:56:53,145] Trial 74 finished with value: 0.857016248153619 and parameters: {'embeddingDimension': 581, 'returnFactor': 3.6121419984386796, 'inOutFactor': 1.9105692911330499, 'walkLength': 275}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:58:16,546] Trial 75 finished with value: 0.8605612998522896 and parameters: {'embeddingDimension': 269, 'returnFactor': 2.8283935043336976, 'inOutFactor': 1.026502750190627, 'walkLength': 653}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 07:58:51,034] Trial 76 finished with value: 0.8581979320531758 and parameters: {'embeddingDimension': 522, 'returnFactor': 2.594962704131123, 'inOutFactor': 0.3422376141114052, 'walkLength': 95}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 08:00:22,250] Trial 77 finished with value: 0.8617429837518463 and parameters: {'embeddingDimension': 464, 'returnFactor': 2.3020873649726177, 'inOutFactor': 2.656666757223273, 'walkLength': 476}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 08:00:43,757] Trial 78 finished with value: 0.865288035450517 and parameters: {'embeddingDimension': 111, 'returnFactor': 3.314502985313684, 'inOutFactor': 2.854083871402012, 'walkLength': 224}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 08:00:55,873] Trial 79 finished with value: 0.8576070901033972 and parameters: {'embeddingDimension': 369, 'returnFactor': 3.0374313331217024, 'inOutFactor': 3.0979515838196243, 'walkLength': 43}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 08:02:22,865] Trial 80 finished with value: 0.8620384047267355 and parameters: {'embeddingDimension': 167, 'returnFactor': 2.725839892275757, 'inOutFactor': 0.47257688487705785, 'walkLength': 416}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 08:04:55,909] Trial 81 finished with value: 0.863810930576071 and parameters: {'embeddingDimension': 667, 'returnFactor': 3.686222913613211, 'inOutFactor': 4.342284979555301, 'walkLength': 598}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 08:07:37,631] Trial 82 finished with value: 0.8623338257016246 and parameters: {'embeddingDimension': 623, 'returnFactor': 3.6414311892926743, 'inOutFactor': 3.7138938243455435, 'walkLength': 675}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 08:10:07,296] Trial 83 finished with value: 0.8658788774002956 and parameters: {'embeddingDimension': 691, 'returnFactor': 3.7023093433373395, 'inOutFactor': 4.242989436821799, 'walkLength': 569}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 08:12:21,578] Trial 84 finished with value: 0.8567208271787298 and parameters: {'embeddingDimension': 558, 'returnFactor': 4.021890138941625, 'inOutFactor': 3.932473732626706, 'walkLength': 622}. Best is trial 23 with value: 0.8697193500738551.
# [I 2023-01-11 08:14:02,929] Trial 85 finished with value: 0.8709010339734121 and parameters: {'embeddingDimension': 458, 'returnFactor': 2.4099447061935733, 'inOutFactor': 4.860897814836788, 'walkLength': 537}. Best is trial 85 with value: 0.8709010339734121.
# [I 2023-01-11 08:15:30,651] Trial 86 finished with value: 0.8614475627769572 and parameters: {'embeddingDimension': 412, 'returnFactor': 2.3927255881342266, 'inOutFactor': 4.881438999764743, 'walkLength': 498}. Best is trial 85 with value: 0.8709010339734121.
# [I 2023-01-11 08:16:56,883] Trial 87 finished with value: 0.8570162481536189 and parameters: {'embeddingDimension': 470, 'returnFactor': 2.1201262538351417, 'inOutFactor': 4.6205824285739485, 'walkLength': 443}. Best is trial 85 with value: 0.8709010339734121.
# [I 2023-01-11 08:18:20,574] Trial 88 finished with value: 0.8590841949778435 and parameters: {'embeddingDimension': 352, 'returnFactor': 2.0711662602037437, 'inOutFactor': 4.925428495596461, 'walkLength': 536}. Best is trial 85 with value: 0.8709010339734121.
# [I 2023-01-11 08:18:54,056] Trial 89 finished with value: 0.8661742983751847 and parameters: {'embeddingDimension': 82, 'returnFactor': 1.2995574620392234, 'inOutFactor': 4.705510159168893, 'walkLength': 463}. Best is trial 85 with value: 0.8709010339734121.
# [I 2023-01-11 08:19:00,620] Trial 90 finished with value: 0.8720827178729691 and parameters: {'embeddingDimension': 323, 'returnFactor': 0.5666657792831505, 'inOutFactor': 2.5259004945121823, 'walkLength': 2}. Best is trial 90 with value: 0.8720827178729691.
# [I 2023-01-11 08:19:10,057] Trial 91 finished with value: 0.8635155096011818 and parameters: {'embeddingDimension': 291, 'returnFactor': 1.0360383108687143, 'inOutFactor': 1.5558643375173444, 'walkLength': 30}. Best is trial 90 with value: 0.8720827178729691.
# [I 2023-01-11 08:19:18,314] Trial 92 finished with value: 0.8614475627769572 and parameters: {'embeddingDimension': 316, 'returnFactor': 0.45219804050081047, 'inOutFactor': 3.2775881828047586, 'walkLength': 13}. Best is trial 90 with value: 0.8720827178729691.
# [I 2023-01-11 08:19:37,939] Trial 93 finished with value: 0.8552437223042835 and parameters: {'embeddingDimension': 408, 'returnFactor': 0.13364680517333488, 'inOutFactor': 1.8181792937373342, 'walkLength': 64}. Best is trial 90 with value: 0.8720827178729691.
# [I 2023-01-11 08:21:07,051] Trial 94 finished with value: 0.8644017725258495 and parameters: {'embeddingDimension': 364, 'returnFactor': 0.6946161595796798, 'inOutFactor': 2.4802522928605604, 'walkLength': 393}. Best is trial 90 with value: 0.8720827178729691.
# [I 2023-01-11 08:21:26,692] Trial 95 finished with value: 0.8605612998522896 and parameters: {'embeddingDimension': 251, 'returnFactor': 1.8569580261050214, 'inOutFactor': 2.966279030157513, 'walkLength': 125}. Best is trial 90 with value: 0.8720827178729691.
# [I 2023-01-11 08:22:33,152] Trial 96 finished with value: 0.8599704579025109 and parameters: {'embeddingDimension': 122, 'returnFactor': 3.265095131260131, 'inOutFactor': 0.8139734173127959, 'walkLength': 346}. Best is trial 90 with value: 0.8720827178729691.
# [I 2023-01-11 08:23:15,877] Trial 97 finished with value: 0.854357459379616 and parameters: {'embeddingDimension': 494, 'returnFactor': 0.8815230880167915, 'inOutFactor': 2.309223525506875, 'walkLength': 146}. Best is trial 90 with value: 0.8720827178729691.
# [I 2023-01-11 08:24:02,105] Trial 98 finished with value: 0.8608567208271788 and parameters: {'embeddingDimension': 448, 'returnFactor': 0.3835412556367608, 'inOutFactor': 4.5382322248480325, 'walkLength': 170}. Best is trial 90 with value: 0.8720827178729691.
# [I 2023-01-11 08:24:36,079] Trial 99 finished with value: 0.8623338257016249 and parameters: {'embeddingDimension': 344, 'returnFactor': 3.082743274683645, 'inOutFactor': 4.73286919594397, 'walkLength': 203}. Best is trial 90 with value: 0.8720827178729691.
# Accuracy: 0.8720827178729691
# Best hyperparameters: {'embeddingDimension': 323, 'returnFactor': 0.5666657792831505, 'inOutFactor': 2.5259004945121823, 'walkLength': 2}
